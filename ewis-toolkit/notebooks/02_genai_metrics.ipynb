# %% [markdown]
# # GenAI Metrics
# Compute energy per token and carbon per token for workload payloads.

# %%
import json
from pathlib import Path

payload = json.loads(Path('../examples/data/sample_payload.json').read_text())
payload['workload']
# Out:
# ERROR: Could not find a version that satisfies the requirement ewis (from versions: none)
# ERROR: No matching distribution found for ewis
# Note: you may need to restart the kernel to use updated packages.
# {'model_name': 'example-llm',
#  'tokens_per_s': 2500,
#  'energy_kwh': 18.2,
#  'tokens': 9000000.0}

# %%
from ewis.metrics.core import energy_per_token, carbon_per_token

energy_per_token(payload), carbon_per_token(payload)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from ewis.metrics.core import energy_per_token, carbon_per_token
#       3 energy_per_token(payload), carbon_per_token(payload)
#
# ModuleNotFoundError: No module named 'ewis'
