# %% [markdown]
# # Grid Stress EDA
# This notebook is a starter. Load `examples/data/sample_payload.json` and explore metrics.

# %%
import json
from pathlib import Path

payload = json.loads(Path('../examples/data/sample_payload.json').read_text())
payload
# Out:
# {'datacenter_id': 'DC-US-WEST',
#  'region': 'CAISO',
#  'timestamp_utc': '2026-03-03T12:00:00Z',
#  'power_mw': 32.5,
#  'it_load_mw': 26.2,
#  'pue': 1.24,
#  'base_grid_load_mw': 28500,
#  'grid_capacity_mw': 52000,
#  'price_usd_per_mwh': 62.7,
#  'carbon_intensity_kgco2_per_mwh': 180,
#  'ambient_temp_c': 22.1,
#  'humidity_pct': 41.0,
#  'workload': {'model_name': 'example-llm',
#   'tokens_per_s': 2500,
#   'energy_kwh': 18.2,
#   'tokens': 9000000.0}}

# %%
from ewis.metrics.core import grid_stress_index

result = grid_stress_index(payload)
result
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from ewis.metrics.core import grid_stress_index
#       3 result = grid_stress_index(payload)
#       4 result
#
# ModuleNotFoundError: No module named 'ewis'
