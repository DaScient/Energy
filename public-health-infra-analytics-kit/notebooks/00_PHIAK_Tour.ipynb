# %% [markdown]
# # PHIAK Tour
# This repo is designed to run from CLI and feed a static dashboard.

# %% [markdown]
# Run:
# ```
# phiak diagnose --config examples/configs/minimal.yml --out reports/latest_report.json
# python -m http.server 8080
# ```
# Open:
# http://localhost:8080/webapp/
